# %% [markdown]
# # Analysis of the hazard data

# %% [markdown]
# ## Import and helper functions

# %%
import os
import codecs
import csv
from datetime import datetime
import numpy as np
import seaborn as sns
import matplotlib.cm as cm
import matplotlib.mlab as ml
from scipy.stats import kendalltau
import pandas as pd
from pylab import savefig


# Read UTF-16 encoded unicode '.txt'. Usefull for cross-platform encoding.
def load_csv(location):
    d = []
    f=codecs.open(location,"rb")
    csvread=csv.reader(f, delimiter=';')
    csvread.next()
    for row in csvread:
        d.append(row)
    
    # Filtering the data where Eye Tracking is not working
    return [line for line in d]  

# Read UTF-16 encoded unicode '.txt'. Usefull for cross-platform encoding.
def load_tsv(location):
    data = []
    f=codecs.open(location,"rb","utf-16")
    csvread=csv.reader(f,delimiter='\t')
    csvread.next()
    for row in csvread:
        data.append(row)
    
    # Filtering the data where Eye Tracking is not working
    return data 

def convert_time(time):
    return datetime.strptime(time, '%M:%S,%f')

# Small script to load all the data from the folder
data = []
directory = os.path.join("c:\\","/media/sf_EyeTracking/results/hazards")
for root,dirs,files in os.walk(directory):
    print(str(len(files)) + " files found.") 
    for file in files:
        if file.endswith(".csv"):
            data.extend(load_csv("/media/sf_EyeTracking/results/hazards/"+file))
data = [line for line in data if line[0] != '']
print(str(len(data)) + " lines of file.")

def per_hazard(tmp, value):
    per_hazard = [line for line in tmp if line[4] == value]
    return per_hazard

def per_participant(tmp, participant):
    per_participant = [line for line in tmp if line[0] == participant]
    return per_participant
# Out:
# 63 files found.
# 1992 lines of file.

# %% [markdown]
# ## Applying corrections and validating to the collected CSV data.

# %%
# Correcting an error made in the file template. 
def correct_line(line):
    # For tryout1, 2nd hazard is 3CH and not 2CH.
    new_line = line
    if line[2] == '1' and line[3] == '2' and line[4] == '2CH':
        new_line[4] = '3CH'
    if line[16] == '7+':
        new_line[16] = '8'
    return new_line

print("Correction done.")

data = [correct_line(line) for line in data]
# Out:
# Correction done.

# %%
# Validate the data by checking occurence order, or consistency between colums.
def validate_line(line):
    # Verify that cross event is after first fixation, if one.
    seconds = convert_time(line[14]) - convert_time(line[6])
    if seconds.total_seconds() < 0:
        return False

    # Verify that there is no typo in cross event.
    seconds = convert_time(line[14]) - convert_time("5:00,0")
    if seconds.total_seconds() > 0:
        return False
    
    # Verify that there is no typo in first fixation.
    seconds = convert_time(line[6]) - convert_time("05:00,0")
    if seconds.total_seconds() > 0:
        return False
    
    # Verify that there fixation number is higher than detection number.
    if int(line[16]) < int(line[15]):
        return False
    
    # Verify that the number of fixations is the good one.
    return validate_fixations(line)


def validate_fixations(line):
    nb = int(line[16]) + 7
    for i in range(7, nb):
        if line[i] == '0':
            return False
    return True

participant_values = list(set([line[0] for line in data if line[0] != '']))
hazard_values = list(set([line[4] for line in data if line[4] != '']))

def validate_data(tmp):
    for line in tmp:
        if validate_line(line) is False:
            print(line)
            
    # Verifying the number of distinct hazards.
    if len(hazard_values) != 24:
        return False
    
    # Verifying the number of distinct participants.
    if len(participant_values) != 63:
        return False
    
    # Success case
    return "Data has been validated."
            
validate_data(data)
# Out:
# 'Data has been validated.'

# %% [markdown]
# ## Pre-analysis of the hazards

# %%
# Computing the fixation time percentage and time difference between first fixation and hazard.

results = []

for line in data:
    new_line = line
    time_advance = 0
    total_fixation = 0
    
    
    if (line[6] != '' and line[14] != ''):
        time_advance = convert_time(line[14]) - convert_time(line[6])
        for i in range(7,14):
            if isinstance(line[i], basestring):
                line[i] = line[i].replace(',','.')
        total_fixation = float(line[7]) + float(line[8]) + float(line[9]) + float(line[10]) + float(line[11])+ float(line[12]) + float(line[13])
        time_advance = time_advance.total_seconds()
    
    percentage = 0
    if time_advance != 0:
        percentage = round(total_fixation / time_advance * 100,3)
    # Sometimes percentage can be over 100 due to the roundings, correct it.
    if percentage > 100:
        percentage = 100
    
    new_line.append(time_advance)
    new_line.append(percentage)
    results.append(new_line)
    new_line = []

# %%
# Verifying if some strange results inside the new computations.
for l in results:
    if l[18] < 0 or l[19] > 100 or l[19] < 0:
        print(l)

# %% [markdown]
# ## Results Generation

# %%
def average(_list, index):
    average = 0
    for l in _list:
        average += float(l[index])
    return round(average / len(_list), 3)  

def std(_list, index):
    new_list = [l[index] for l in _list]
    arr = np.array(new_list).astype(np.float)
    return round(np.std(arr), 3)

def stops(_list):
    return len([l for l in _list if l[15] < l[16]]) * 100 / len(_list)

def analyse(tmp):
    yes = [line for line in tmp if line[5] == 'YES']
    no = [line for line in tmp if line[5] == 'NO']
    accuracy = len(yes) * 100 / (len(yes) + len(no))
    """
    print("Analysis made on " + str(len(data)) + " lines")
    print("Number of hazards seen by the participants: " + str(len(yes)))
    print("Mean values:")
    print("1) Accuracy: " + str(accuracy) + " %")
    print("2) Average first fixation duration: " + str(average(yes, 7))) 
    print("3) Average time of first fixation before hazard: " + str(average(yes, 18)))
    print("4) Average fixation percentage during hazard: " + str(average(yes, 19)) +" %")
    print("5) Average fixation number on hazard: " + str(average(yes, 16)))
    print("6) Average fixation number on hazard as detection: " + str(average(yes, 15)))
    print("7) Average percentage of stops on hazards while driving: " + str(stops(yes)) + " %")
    print("Deviation values:")
    print("2) Standard deviation of first fixation duration: " + str(std(yes, 7)))
    print("3) Standard deviation of time of first fixation: " + str(std(yes, 18)))
    print("4) Standard deviation of fixation percentage during hazard: " + str(std(yes, 19)) +" %")
    print("5) Standard deviation for fixation number on hazard: " + str(std(yes, 16)))
    print("6) Standard deviation for fixation number on hazard as detection: " + str(std(yes, 15)))
    print("----------------------------------------")
    """
    result = [accuracy, average(yes, 7), std(yes, 7), average(yes, 18), std(yes, 18), average(yes, 19), std(yes, 19)]
    result.extend([average(yes, 16), std(yes, 16), average(yes, 15), std(yes, 15), stops(yes)])
    return result

def analyse_participant(ID):
    tmp = [line for line in results if line[0] == ID]
    print("Participant " + str(ID) + " - " + str(len(tmp)) + " lines")
    analyse(tmp)    
    
for participant in participant_values:
    analyse_participant(participant)
# Out:
# Participant 56 - 32 lines
# Participant 54 - 32 lines
# Participant 42 - 32 lines
# Participant 43 - 24 lines
# Participant 60 - 32 lines
# Participant 61 - 32 lines
# Participant 62 - 32 lines
# Participant 63 - 32 lines
# Participant 64 - 32 lines
# Participant 49 - 32 lines
# Participant 66 - 32 lines
# Participant 67 - 32 lines
# Participant 68 - 32 lines
# Participant 69 - 32 lines
# Participant 52 - 32 lines
# Participant 24 - 32 lines
# Participant 25 - 32 lines
# Participant 27 - 32 lines
# Participant 20 - 32 lines
# Participant 21 - 32 lines
# Participant 22 - 32 lines
# Participant 23 - 32 lines
# Participant 46 - 24 lines
# Participant 47 - 24 lines
# Participant 44 - 32 lines
# Participant 45 - 32 lines
# Participant 28 - 32 lines
# Participant 29 - 32 lines
# Participant 40 - 32 lines
# Participant 41 - 32 lines
# Participant 2 - 32 lines
# Participant 5 - 32 lines
# Participant 4 - 32 lines
# Participant 7 - 32 lines
# Participant 6 - 32 lines
# Participant 9 - 32 lines
# Participant 8 - 32 lines
# Participant 39 - 32 lines
# Participant 65 - 32 lines
# Participant 38 - 32 lines
# Participant 71 - 32 lines
# Participant 70 - 32 lines
# Participant 59 - 32 lines
# Participant 58 - 32 lines
# Participant 11 - 32 lines
# Participant 13 - 32 lines
# Participant 12 - 32 lines
# Participant 15 - 32 lines
# Participant 14 - 32 lines
# Participant 17 - 32 lines
# Participant 16 - 32 lines
# Participant 33 - 32 lines
# Participant 18 - 32 lines
# Participant 31 - 32 lines
# Participant 30 - 32 lines
# Participant 51 - 32 lines
# Participant 36 - 32 lines
# Participant 53 - 32 lines
# Participant 34 - 32 lines
# Participant 55 - 32 lines
# Participant 48 - 32 lines
# Participant 57 - 32 lines
# Participant 50 - 32 lines

# %%
analyse(results)
analyse_participant('30')
# Out:
# Participant 30 - 32 lines

# %% [raw]
# Analysis made on 1992 lines
# Number of hazards seen by the participants: 1669
# Mean values:
# 1) Accuracy: 85 %
# 2) Average first fixation duration: 1.187
# 3) Average time of first fixation before hazard: 5.264
# 4) Average fixation percentage during hazard: 53.92 %
# 5) Average fixation number on hazard: 2.747
# 6) Average fixation number on hazard as detection: 1.394
# 7) Average percentage of stops on hazards while driving: 11 %
# Deviation values:
# 2) Standard deviation of first fixation duration: 1.083
# 3) Standard deviation of time of first fixation: 5.994
# 4) Standard deviation of fixation percentage during hazard: 21.998 %
# 5) Standard deviation for fixation number on hazard: 2.747
# 6) Standard deviation for fixation number on hazard as detection: 1.394

# %%
# To generate the corrected raw tables.
def generate_data_per_participant(save=False):
    
    a = [["Participant", "Record_Name", "Track", "Hazard_number", "Hazard_type", "Seen", "First fixation time", 
          "First fixation", "Second fixation", "Third fixation", "Fouth fixation", "Fifth fixation", 
          "Sixth fixation", "Seventh fixation", "Cross event", "Detections", "Fixations", "Remarks",
          "Detection laps", "Percentage of fixation during hazard"]]
    
    for value in participant_values:
        if save == True:
            a = [["Participant", "Record_Name", "Track", "Hazard_number", "Hazard_type", "Seen", "First fixation time", 
              "First fixation", "Second fixation", "Third fixation", "Fouth fixation", "Fifth fixation", 
              "Sixth fixation", "Seventh fixation", "Cross event", "Detections", "Fixations", "Remarks",
              "Detection laps", "Percentage of fixation during hazard"]]
        
        a.extend(per_participant(data, value))
        
        if save == True:
            with open("data/data_per_participant/participant_data_"+value+".csv", "wb") as f:
                writer = csv.writer(f, delimiter = ';')
                writer.writerows(a)
    return a

generate_data_per_participant(save = True)
# Out:
# [['Participant',
#   'Record_Name',
#   'Track',
#   'Hazard_number',
#   'Hazard_type',
#   'Seen',
#   'First fixation time',
#   'First fixation',
#   'Second fixation',
#   'Third fixation',
#   'Fouth fixation',
#   'Fifth fixation',
#   'Sixth fixation',
#   'Seventh fixation',
#   'Cross event',
#   'Detections',
#   'Fixations',
#   'Remarks',
#   'Detection laps',
#   'Percentage of fixation during hazard'],
#  ['50',
#   'Recording206',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:12,2',
#   '0.68',
#   '2.36',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:16,8',
#   '2',
#   '2',
#   'offset',
#   4.6,
#   66.087],
#  ['50',
#   'Recording206',
#   '1',
#   '2',
#   '3CH',
#   'YES',
#   '00:34,2',
#   '0.4',
#   '0.24',
#   '0.2',
#   '0.68',
#   '0',
#   '0',
#   '0',
#   '00:40,6',
#   '4',
#   '4',
#   '',
#   6.4,
#   23.75],
#  ['50',
#   'Recording206',
#   '1',
#   '3',
#   '2AV',
#   'YES',
#   '00:55,7',
#   '2.14',
#   '0.24',
#   '1.7',
#   '0',
#   '0',
#   '0',
#   '0',
#   '01:01,2',
#   '3',
#   '3',
#   '',
#   5.5,
#   74.182],
#  ['50',
#   'Recording206',
#   '1',
#   '4',
#   '5CV',
#   'YES',
#   '01:20,0',
#   '0.74',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '01:20,9',
#   '1',
#   '1',
#   '',
#   0.9,
#   82.222],
#  ['50',
#   'Recording206',
#   '1',
#   '5',
#   '1CV',
#   'YES',
#   '01:39,3',
#   '2.549',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '01:42,9',
#   '1',
#   '1',
#   '',
#   3.6,
#   70.806],
#  ['50',
#   'Recording206',
#   '1',
#   '6',
#   '6AV',
#   'YES',
#   '01:47,4',
#   '2.38',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '01:50,3',
#   '1',
#   '1',
#   '',
#   2.9,
#   82.069],
#  ['50',
#   'Recording206',
#   '1',
#   '7',
#   '4AH',
#   'YES',
#   '01:57,6',
#   '1.02',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '01:59,9',
#   '1',
#   '1',
#   '',
#   2.3,
#   44.348],
#  ['50',
#   'Recording206',
#   '1',
#   '8',
#   '6CH',
#   'NO',
#   '00:00,0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:00,0',
#   '0',
#   '0',
#   'visible late',
#   0.0,
#   0],
#  ['50',
#   'Recording205',
#   '2',
#   '1',
#   '1CH',
#   'YES',
#   '00:16,9',
#   '0.68',
#   '2.18',
#   '0.02',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:22,9',
#   '3',
#   '3',
#   '2 and 3 together',
#   6.0,
#   48.0],
#  ['50',
#   'Recording205',
#   '2',
#   '2',
#   '2AH',
#   'YES',
#   '00:43,9',
#   '1.18',
#   '2.32',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:49,3',
#   '2',
#   '2',
#   'offset',
#   5.4,
#   64.815],
#  ['50',
#   'Recording205',
#   '2',
#   '3',
#   '4CV',
#   'YES',
#   '01:06,7',
#   '1.84',
#   '3.241',
#   '0.64',
#   '0',
#   '0',
#   '0',
#   '0',
#   '01:14,8',
#   '2',
#   '3',
#   '',
#   8.1,
#   70.63],
#  ['50',
#   'Recording205',
#   '2',
#   '4',
#   '5AV',
#   'NO',
#   '00:00,0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:00,0',
#   '0',
#   '0',
#   'hard to guess due to offset',
#   0.0,
#   0],
#  ['50',
#   'Recording205',
#   '2',
#   '5',
#   '3AV',
#   'YES',
#   '01:38,6',
#   '0.6',
#   '0.32',
#   '0.44',
#   '0.58',
#   '0.14',
#   '0',
#   '0',
#   '01:43,4',
#   '5',
#   '5',
#   '',
#   4.8,
#   43.333],
#  ['50',
#   'Recording205',
#   '2',
#   '6',
#   '3AH',
#   'YES',
#   '01:54,7',
#   '0.52',
#   '0.82',
#   '1.5',
#   '1.4',
#   '0',
#   '0',
#   '0',
#   '02:00,3',
#   '4',
#   '4',
#   '',
#   5.6,
#   75.714],
#  ['50',
#   'Recording205',
#   '2',
#   '7',
#   '2CV',
#   'YES',
#   '02:10,2',
#   '0.68',
#   '3.081',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '02:14,6',
#   '2',
#   '2',
#   '',
#   4.4,
#   85.477],
#  ['50',
#   'Recording205',
#   '2',
#   '8',
#   '6AH',
#   'YES',
#   '02:28,1',
#   '0.12',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '02:28,7',
#   '1',
#   '1',
#   'hard to see it',
#   0.6,
#   20.0],
#  ['50',
#   'Recording204',
#   '3',
#   '1',
#   '6CV',
#   'YES',
#   '00:21,0',
#   '0.82',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:22,4',
#   '0',
#   '0',
#   '',
#   1.4,
#   58.571],
#  ['50',
#   'Recording204',
#   '3',
#   '2',
#   '4CH',
#   'YES',
#   '00:24,4',
#   '0.88',
#   '0.74',
#   '0.22',
#   '0.32',
#   '0',
#   '0',
#   '0',
#   '00:31,5',
#   '2',
#   '4',
#   '',
#   7.1,
#   30.423],
#  ['50',
#   'Recording204',
#   '3',
#   '3',
#   '5AH',
#   'NO',
#   '00:00,0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:00,0',
#   '0',
#   '0',
#   '',
#   0.0,
#   0],
#  ['50',
#   'Recording204',
#   '3',
#   '4',
#   '4AV',
#   'YES',
#   '01:01,9',
#   '0.6',
#   '0.84',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '01:05,4',
#   '2',
#   '2',
#   '',
#   3.5,
#   41.143],
#  ['50',
#   'Recording204',
#   '3',
#   '5',
#   '5CH',
#   'NO',
#   '00:00,0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:00,0',
#   '0',
#   '0',
#   '',
#   0.0,
#   0],
#  ['50',
#   'Recording204',
#   '3',
#   '6',
#   '2CH',
#   'YES',
#   '01:32,4',
#   '0.5',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '01:36,4',
#   '1',
#   '1',
#   'lost it ',
#   4.0,
#   12.5],
#  ['50',
#   'Recording204',
#   '3',
#   '7',
#   '3CV',
#   'YES',
#   '01:49,3',
#   '1.295',
#   '0.2',
#   '2.03',
#   '0.671',
#   '1.22',
#   '0.54',
#   '0.94',
#   '01:56,6',
#   '7',
#   '7',
#   '',
#   7.3,
#   94.466],
#  ['50',
#   'Recording204',
#   '3',
#   '8',
#   '1AV',
#   'YES',
#   '02:17,8',
#   '2.2',
#   '0.6',
#   '1.12',
#   '0.38',
#   '0',
#   '0',
#   '0',
#   '02:25,0',
#   '2',
#   '4',
#   '',
#   7.2,
#   59.722],
#  ['50',
#   'Recording203',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:17,1',
#   '0.24',
#   '2.14',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:21,4',
#   '2',
#   '2',
#   '',
#   4.3,
#   55.349],
#  ['50',
#   'Recording203',
#   '1',
#   '2',
#   '3CH',
#   'YES',
#   '00:41,6',
#   '1.02',
#   '0.7',
#   '1.3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:47,6',
#   '3',
#   '3',
#   '',
#   6.0,
#   50.333],
#  ['50',
#   'Recording203',
#   '1',
#   '3',
#   '2AV',
#   'YES',
#   '01:02,7',
#   '0.34',
#   '1.1',
#   '0.72',
#   '0.18',
#   '1.58',
#   '0',
#   '0',
#   '01:10,1',
#   '5',
#   '5',
#   '',
#   7.4,
#   52.973],
#  ['50',
#   'Recording203',
#   '1',
#   '4',
#   '5CV',
#   'YES',
#   '01:26,5',
#   '0.26',
#   '0.24',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '01:34,6',
#   '2',
#   '2',
#   '',
#   8.1,
#   6.173],
#  ['50',
#   'Recording203',
#   '1',
#   '5',
#   '1CV',
#   'YES',
#   '01:52,2',
#   '4.601',
#   '1.18',
#   '0.42',
#   '0.92',
#   '1.32',
#   '0',
#   '0',
#   '02:04,3',
#   '1',
#   '5',
#   '',
#   12.1,
#   69.76],
#  ['50',
#   'Recording203',
#   '1',
#   '6',
#   '6AV',
#   'NO',
#   '00:00,0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:00,0',
#   '0',
#   '0',
#   'hard to see',
#   0.0,
#   0],
#  ['50',
#   'Recording203',
#   '1',
#   '7',
#   '4AH',
#   'YES',
#   '02:17,9',
#   '3.241',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '02:21,8',
#   '1',
#   '1',
#   '',
#   3.9,
#   83.103],
#  ['50',
#   'Recording203',
#   '1',
#   '8',
#   '6CH',
#   'NO',
#   '00:00,0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:00,0',
#   '0',
#   '0',
#   '',
#   0.0,
#   0]]

# %%
# To generate tables by hazard
def generate_data_per_hazard(save=False):
    a = [["Participant", "Record_Name", "Track", "Hazard_number", "Hazard_type", "Seen", "First fixation time", 
          "First fixation", "Second fixation", "Third fixation", "Fouth fixation", "Fifth fixation", 
          "Sixth fixation", "Seventh fixation", "Cross event", "Detections", "Fixations", "Remarks",
          "Detection laps", "Percentage of fixation during hazard"]]
    for value in hazard_values:
        if save ==True:
            a = [["Participant", "Record_Name", "Track", "Hazard_number", "Hazard_type", "Seen", "First fixation time", 
              "First fixation", "Second fixation", "Third fixation", "Fouth fixation", "Fifth fixation", 
              "Sixth fixation", "Seventh fixation", "Cross event", "Detections", "Fixations", "Remarks",
              "Detection laps", "Percentage of fixation during hazard"]]
        
        a.extend(per_hazard(results, value))
        
        if save == True:
            with open("data/data_per_hazard/hazard_"+value+".csv", "wb") as f:
                writer = csv.writer(f, delimiter = ';')
                writer.writerows(a)
    return a

generate_data_per_hazard(save=True)
# Out:
# [['Participant',
#   'Record_Name',
#   'Track',
#   'Hazard_number',
#   'Hazard_type',
#   'Seen',
#   'First fixation time',
#   'First fixation',
#   'Second fixation',
#   'Third fixation',
#   'Fouth fixation',
#   'Fifth fixation',
#   'Sixth fixation',
#   'Seventh fixation',
#   'Cross event',
#   'Detections',
#   'Fixations',
#   'Remarks',
#   'Detection laps',
#   'Percentage of fixation during hazard'],
#  ['2',
#   'Recording008',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:35,2',
#   '0.46',
#   '2.48',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:40,6',
#   '2',
#   '2',
#   'left offset',
#   5.4,
#   54.444],
#  ['4',
#   'Recording012',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:23,6',
#   '0.6',
#   '2.04',
#   '0.66',
#   '0.68',
#   '0.46',
#   '0',
#   '0',
#   '00:32,5',
#   '4',
#   '5',
#   '',
#   8.9,
#   49.888],
#  ['5',
#   'Recording017',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:22,5',
#   '0.54',
#   '2.62',
#   '0.38',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:28,3',
#   '3',
#   '3',
#   '',
#   5.8,
#   61.034],
#  ['6',
#   'Recording032',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:26,7',
#   '0.52',
#   '3.681',
#   '0.56',
#   '0.82',
#   '0',
#   '0',
#   '0',
#   '00:36,6',
#   '2',
#   '4',
#   '',
#   9.9,
#   56.374],
#  ['7',
#   'Recording037',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:29,0',
#   '1',
#   '1.32',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:34,9',
#   '2',
#   '2',
#   'quite a lot of offset',
#   5.9,
#   39.322],
#  ['7',
#   'Recording034',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:32,6',
#   '0.3',
#   '0.86',
#   '0.4',
#   '1.24',
#   '0',
#   '0',
#   '0',
#   '00:38,0',
#   '4',
#   '4',
#   'some offset, 2 and 3 together',
#   5.4,
#   51.852],
#  ['8',
#   'Recording041',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:22,7',
#   '0.824',
#   '0.66',
#   '1.24',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:27,5',
#   '3',
#   '3',
#   '',
#   4.8,
#   56.75],
#  ['8',
#   'Recording038',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:19,1',
#   '3.001',
#   '1.24',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:27,2',
#   '2',
#   '2',
#   '',
#   8.1,
#   52.358],
#  ['9',
#   'Recording043',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:29,5',
#   '1.88',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:32,7',
#   '1',
#   '1',
#   '',
#   3.2,
#   58.75],
#  ['11',
#   'Recording049',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:30,2',
#   '0.68',
#   '4.621',
#   '0.98',
#   '0.3',
#   '0',
#   '0',
#   '0',
#   '00:41,7',
#   '2',
#   '4',
#   '',
#   11.5,
#   57.226],
#  ['12',
#   'Recording053',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:21,4',
#   '0.28',
#   '0.26',
#   '2.3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:28,2',
#   '3',
#   '3',
#   '',
#   6.8,
#   41.765],
#  ['13',
#   'Recording058',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:20,3',
#   '0.34',
#   '0.935',
#   '0.191',
#   '2.156',
#   '0.58',
#   '0',
#   '0',
#   '00:30,2',
#   '5',
#   '5',
#   'some offset, 3 and 4 together',
#   9.9,
#   42.444],
#  ['13',
#   'Recording055',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:22,1',
#   '2.78',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:26,7',
#   '1',
#   '1',
#   '',
#   4.6,
#   60.435],
#  ['14',
#   'Recording063',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:18,9',
#   '1.3',
#   '0.88',
#   '1.96',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:25,9',
#   '3',
#   '3',
#   '',
#   7.0,
#   59.143],
#  ['14',
#   'Recording060',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:17,1',
#   '0.78',
#   '2.32',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:22,5',
#   '2',
#   '2',
#   '',
#   5.4,
#   57.407],
#  ['15',
#   'Recording067',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:31,9',
#   '1.12',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:34,2',
#   '1',
#   '1',
#   'offset',
#   2.3,
#   48.696],
#  ['16',
#   'Recording072',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:14,3',
#   '3.061',
#   '2.18',
#   '0.4',
#   '0.56',
#   '0',
#   '0',
#   '0',
#   '00:24,5',
#   '2',
#   '4',
#   '2 and 3 together',
#   10.2,
#   60.794],
#  ['16',
#   'Recording069',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:21,0',
#   '4.421',
#   '0.24',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:27,5',
#   '1',
#   '2',
#   '',
#   6.5,
#   71.708],
#  ['17',
#   'Recording075',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:26,1',
#   '2.4',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:29,6',
#   '1',
#   '1',
#   '',
#   3.5,
#   68.571],
#  ['18',
#   'Recording079',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:18,9',
#   '0.76',
#   '1.22',
#   '0.8',
#   '0.28',
#   '1.14',
#   '0.36',
#   '0',
#   '00:30,6',
#   '3',
#   '6',
#   '4 and 5 together',
#   11.7,
#   38.974],
#  ['20',
#   'Recording082',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:24,8',
#   '0.9',
#   '0.18',
#   '0.24',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:28,1',
#   '3',
#   '3',
#   '',
#   3.3,
#   40.0],
#  ['21',
#   'Recording088',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:16,0',
#   '1.1',
#   '2',
#   '1.64',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:23,7',
#   '3',
#   '3',
#   '',
#   7.7,
#   61.558],
#  ['21',
#   'Recording085',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:26,5',
#   '0.82',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:28,6',
#   '1',
#   '1',
#   '',
#   2.1,
#   39.048],
#  ['22',
#   'Recording092',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:23,9',
#   '2.82',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:29,1',
#   '1',
#   '1',
#   '',
#   5.2,
#   54.231],
#  ['22',
#   'Recording089',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:30,9',
#   '0.54',
#   '1.66',
#   '0.28',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:37,3',
#   '2',
#   '3',
#   '',
#   6.4,
#   38.75],
#  ['23',
#   'Recording094',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:21,5',
#   '0.22',
#   '3.126',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:26,9',
#   '2',
#   '2',
#   'a lot of offset',
#   5.4,
#   61.963],
#  ['24',
#   'Recording098',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:33,3',
#   '0.38',
#   '2.52',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:40,1',
#   '1',
#   '1',
#   '',
#   6.8,
#   42.647],
#  ['25',
#   'Recording103',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:19,3',
#   '0.08',
#   '0.34',
#   '0.96',
#   '0.08',
#   '0',
#   '0',
#   '0',
#   '00:23,9',
#   '4',
#   '4',
#   '3 and 4 together',
#   4.6,
#   31.739],
#  ['27',
#   'Recording108',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:23,5',
#   '0.32',
#   '2.68',
#   '0.26',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:29,5',
#   '3',
#   '3',
#   '',
#   6.0,
#   54.333],
#  ['27',
#   'Recording105',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:36,9',
#   '1.16',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:39,9',
#   '1',
#   '1',
#   '',
#   3.0,
#   38.667],
#  ['28',
#   'Recording112',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:23,3',
#   '0.76',
#   '0.54',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:26,7',
#   '2',
#   '2',
#   'pretty bad quality',
#   3.4,
#   38.235],
#  ['28',
#   'Recording109',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:26,1',
#   '0.3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:26,7',
#   '1',
#   '1',
#   '',
#   0.6,
#   50.0],
#  ['29',
#   'Recording114',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:29,2',
#   '1.36',
#   '2.74',
#   '0.46',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:36,9',
#   '3',
#   '3',
#   '',
#   7.7,
#   59.221],
#  ['30',
#   'Recording118',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:28,3',
#   '0.36',
#   '0.44',
#   '2.02',
#   '0.18',
#   '0.6',
#   '0.48',
#   '0',
#   '00:40,8',
#   '3',
#   '6',
#   '',
#   12.5,
#   32.64],
#  ['31',
#   'Recording124',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:21,4',
#   '1.4',
#   '4.021',
#   '0.56',
#   '0.56',
#   '0.56',
#   '0.56',
#   '0',
#   '00:32,3',
#   '2',
#   '6',
#   '',
#   10.9,
#   70.284],
#  ['33',
#   'Recording133',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:32,4',
#   '0.24',
#   '0.96',
#   '2.16',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:38,1',
#   '3',
#   '3',
#   'offset',
#   5.7,
#   58.947],
#  ['33',
#   'Recording129',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:46,7',
#   '2.8',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:51,3',
#   '1',
#   '1',
#   'offset',
#   4.6,
#   60.87],
#  ['34',
#   'Recording138',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:28,2',
#   '0.48',
#   '0.34',
#   '0.3',
#   '0.26',
#   '0',
#   '0',
#   '0',
#   '00:38,8',
#   '3',
#   '4',
#   '',
#   10.6,
#   13.019],
#  ['34',
#   'Recording134',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:59,1',
#   '0.16',
#   '0.8',
#   '2.5',
#   '0.22',
#   '0.5',
#   '0.46',
#   '0.38',
#   '01:11,5',
#   '3',
#   '7',
#   '',
#   12.4,
#   40.484],
#  ['36',
#   'Recording144',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:24,1',
#   '0.44',
#   '0.44',
#   '2.62',
#   '0.6',
#   '0.26',
#   '0',
#   '0',
#   '00:30,7',
#   '3',
#   '5',
#   '',
#   6.6,
#   66.061],
#  ['38',
#   'Recordnig153',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:31,9',
#   '2.9',
#   '0.22',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:37,8',
#   '2',
#   '2',
#   '',
#   5.9,
#   52.881],
#  ['39',
#   'Recording157',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:22,1',
#   '0.74',
#   '2.74',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:30,1',
#   '2',
#   '2',
#   '',
#   8.0,
#   43.5],
#  ['40',
#   'Recording161',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:30,7',
#   '0.2',
#   '2.468',
#   '0.4',
#   '1.04',
#   '0.9',
#   '0.12',
#   '0',
#   '00:39,5',
#   '4',
#   '6',
#   'offset',
#   8.8,
#   58.273],
#  ['41',
#   'Recording168',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:13,4',
#   '0.46',
#   '2.4',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:20,3',
#   '2',
#   '2',
#   'Good quality',
#   6.9,
#   41.449],
#  ['41',
#   'Recording164',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:11,9',
#   '1.38',
#   '5.321',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:22,1',
#   '2',
#   '2',
#   'offset',
#   10.2,
#   65.696],
#  ['42',
#   'Recording171',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:19,5',
#   '1.68',
#   '3.041',
#   '0.36',
#   '0.46',
#   '0',
#   '0',
#   '0',
#   '00:28,7',
#   '2',
#   '4',
#   'Pretty good quality',
#   9.2,
#   60.228],
#  ['43',
#   'Recording175',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:20,0',
#   '0.5',
#   '1.28',
#   '2.26',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:25,7',
#   '3',
#   '3',
#   'good quality',
#   5.7,
#   70.877],
#  ['44',
#   'Recording183',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:27,7',
#   '1.02',
#   '0.62',
#   '1.7',
#   '0.22',
#   '1.44',
#   '0',
#   '0',
#   '00:36,0',
#   '5',
#   '5',
#   'average quality',
#   8.3,
#   60.241],
#  ['44',
#   'Recording179',
#   '1',
#   '1',
#   '1AH',
#   'CRASH',
#   '00:00,0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:00,0',
#   '0',
#   '0',
#   'no side screens',
#   0.0,
#   0],
#  ['45',
#   'Recording185',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:30,9',
#   '2.54',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:34,7',
#   '1',
#   '1',
#   'some offset',
#   3.8,
#   66.842],
#  ['46',
#   'Recording190',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:13,4',
#   '0.58',
#   '3.081',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:20,0',
#   '2',
#   '2',
#   'offset',
#   6.6,
#   55.47],
#  ['47',
#   'Recording192',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:36,0',
#   '1.06',
#   '0.9',
#   '0.06',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:38,8',
#   '3',
#   '3',
#   '',
#   2.8,
#   72.143],
#  ['48',
#   'Recording197',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:15,5',
#   '1.94',
#   '0.38',
#   '2.64',
#   '0.34',
#   '0.18',
#   '0',
#   '0',
#   '00:23,3',
#   '5',
#   '5',
#   '4 and 5 together',
#   7.8,
#   70.256],
#  ['49',
#   'Recording200',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:12,3',
#   '0.66',
#   '0.42',
#   '3.261',
#   '0.28',
#   '0.18',
#   '0',
#   '0',
#   '00:22,0',
#   '3',
#   '5',
#   '3 and 4 together',
#   9.7,
#   49.495],
#  ['50',
#   'Recording206',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:12,2',
#   '0.68',
#   '2.36',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:16,8',
#   '2',
#   '2',
#   'offset',
#   4.6,
#   66.087],
#  ['50',
#   'Recording203',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:17,1',
#   '0.24',
#   '2.14',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:21,4',
#   '2',
#   '2',
#   '',
#   4.3,
#   55.349],
#  ['51',
#   'Recording208',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:36,3',
#   '0.96',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:38,3',
#   '1',
#   '1',
#   'some offset',
#   2.0,
#   48.0],
#  ['52',
#   'Recording214',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:33,5',
#   '0.28',
#   '1.68',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:38,2',
#   '2',
#   '2',
#   '',
#   4.7,
#   41.702],
#  ['53',
#   'Recording219',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:16,5',
#   '0.3',
#   '2.901',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:22,4',
#   '2',
#   '2',
#   'some offset (ok)',
#   5.9,
#   54.254],
#  ['53',
#   'Recording216',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:31,2',
#   '0.68',
#   '0.6',
#   '0.24',
#   '0.52',
#   '0',
#   '0',
#   '0',
#   '00:34,6',
#   '4',
#   '4',
#   '',
#   3.4,
#   60.0],
#  ['54',
#   'Recording222',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:18,0',
#   '0.76',
#   '2.24',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:23,5',
#   '2',
#   '2',
#   '',
#   5.5,
#   54.545],
#  ['55',
#   'Recording225',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:14,3',
#   '0.38',
#   '2.56',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:20,1',
#   '2',
#   '2',
#   '',
#   5.8,
#   50.69],
#  ['56',
#   'Recording231',
#   '2',
#   '1',
#   '1AH',
#   'YES',
#   '00:10,1',
#   '0.74',
#   '3.161',
#   '3.581',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:20,9',
#   '2',
#   '3',
#   '',
#   10.8,
#   69.278],
#  ['57',
#   'Recording235',
#   '3',
#   '1',
#   '1AH',
#   'YES',
#   '00:20,8',
#   '1.32',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:24,3',
#   '1',
#   '1',
#   'good quality',
#   3.5,
#   37.714],
#  ['58',
#   'Recording239',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:14,7',
#   '1.12',
#   '3.021',
#   '0.86',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:21,9',
#   '2',
#   '3',
#   '',
#   7.2,
#   69.458],
#  ['59',
#   'Recording243',
#   '3',
#   '1',
#   '1AH',
#   'YES',
#   '00:18,4',
#   '0.98',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:20,2',
#   '1',
#   '1',
#   '',
#   1.8,
#   54.444],
#  ['60',
#   'Recording247',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:13,1',
#   '0.72',
#   '2.3',
#   '0.18',
#   '0.26',
#   '0.36',
#   '0',
#   '0',
#   '00:23,3',
#   '2',
#   '5',
#   'bad quality data (offset)',
#   10.2,
#   37.451],
#  ['61',
#   'Recording251',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:13,6',
#   '3.041',
#   '0.16',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:19,9',
#   '1',
#   '2',
#   'Offset on the data record (results might be less precise)',
#   6.3,
#   50.81],
#  ['62',
#   'Recording257',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:15,1',
#   '0.62',
#   '2.26',
#   '0.12',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:20,0',
#   '3',
#   '3',
#   '',
#   4.9,
#   61.224],
#  ['62',
#   'Recording254',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:14,3',
#   '0.34',
#   '0.76',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:19,5',
#   '2',
#   '2',
#   'offset',
#   5.2,
#   21.154],
#  ['63',
#   'Recording259',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:11,6',
#   '0.44',
#   '3.221',
#   '0.64',
#   '0.18',
#   '0',
#   '0',
#   '0',
#   '00:18,6',
#   '2',
#   '4',
#   '2 and 3 together',
#   7.0,
#   64.014],
#  ['64',
#   'Recording265',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:26,2',
#   '0.38',
#   '3.661',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:36,8',
#   '2',
#   '2',
#   '',
#   10.6,
#   38.123],
#  ['65',
#   'Recording270',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:13,2',
#   '2.921',
#   '2.78',
#   '0.56',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:21,4',
#   '3',
#   '3',
#   '',
#   8.2,
#   76.354],
#  ['65',
#   'Recording267',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:21,7',
#   '0.48',
#   '1.08',
#   '1.4',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:26,3',
#   '3',
#   '3',
#   '2 and 3 together',
#   4.6,
#   64.348],
#  ['66',
#   'Recording273',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:21,4',
#   '3.181',
#   '1.58',
#   '0.58',
#   '0.18',
#   '0',
#   '0',
#   '0',
#   '00:28,8',
#   '4',
#   '4',
#   '',
#   7.4,
#   74.608],
#  ['67',
#   'Recording276',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:21,1',
#   '2.801',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:25,3',
#   '1',
#   '1',
#   'offset (maybe less accurate)',
#   4.2,
#   66.69],
#  ['68',
#   'Recording283',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:22,3',
#   '0.9',
#   '1.44',
#   '1.8',
#   '0.86',
#   '0.64',
#   '0.54',
#   '0.5',
#   '00:33,2',
#   '1',
#   '7',
#   '7, 5 and 6 together, was going slow and braked super far from it',
#   10.9,
#   61.284],
#  ['68',
#   'Recording280',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:20,1',
#   '0.18',
#   '3.841',
#   '1.126',
#   '1.04',
#   '2.08',
#   '0.56',
#   '0.34',
#   '00:33,4',
#   '2',
#   '7',
#   '',
#   13.3,
#   68.925],
#  ['69',
#   'Recording285',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:20,7',
#   '3.381',
#   '0.2',
#   '0.06',
#   '0.16',
#   '0',
#   '0',
#   '0',
#   '00:28,8',
#   '1',
#   '4',
#   '2 and 3 together, some offset',
#   8.1,
#   46.926],
#  ['70',
#   'Recording290',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:18,6',
#   '1.64',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:22,0',
#   '1',
#   '1',
#   'some offset',
#   3.4,
#   48.235],
#  ['71',
#   'Recording295',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:18,2',
#   '1.02',
#   '1.44',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:24,0',
#   '2',
#   '2',
#   '',
#   5.8,
#   42.414],
#  ['71',
#   'Recording292',
#   '1',
#   '1',
#   '1AH',
#   'YES',
#   '00:37,2',
#   '1.14',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '00:39,7',
#   '1',
#   '1',
#   '',
#   2.5,
#   45.6]]

# %%
# To generate tables by hazard
def generate_results_participant(save=False):
    a = [["Participant", "Accuracy", "Average first fixation time", "Std first dixation time",
             "Average laps time between first fixation and hazard", "Std time between first fixation and hazard",
             "Percentage of fixation during hazard", "Std of fixation during hazard",
             "Average number of fixations", "Std of number of fixations",
             "Average number of detections", "Std of number of detections",
             "Percentage of stops"]]
    
    # Adding the average results first
    new_line = ["0"]
    new_line.extend(analyse(results))
    a.append(new_line)
    
    # Adding results participant per participant
    for value in participant_values:
        new_line = [value]
        new_line.extend(analyse(per_participant(results, value)))
        a.append(new_line)
    
    # Writting the results as CSV
    if save == True:
        with open("all_participants_results.csv", "wb") as f:
            writer = csv.writer(f, delimiter = ';')
            writer.writerows(a)
        
    return a

# generate_results_participant()

# %%
# To generate tables by hazard
def generate_results_hazard(save = False):
    a = [["Participant", "Accuracy", "Average first fixation time", "Std first dixation time",
             "Average laps time between first fixation and hazard", "Std time between first fixation and hazard",
             "Percentage of fixation during hazard", "Std of fixation during hazard",
             "Average number of fixations", "Std of number of fixations",
             "Average number of detections", "Std of number of detections",
             "Percentage of stops"]]
    
    # Adding the average results first
    new_line = ["0"]
    new_line.extend(analyse(results))
    a.append(new_line)
    
    # Adding results participant per participant
    for value in hazard_values:
        new_line = [value]
        new_line.extend(analyse(per_hazard(results, value)))
        a.append(new_line)
    
    # Writting the results as CSV
    if save == True:
        with open("all_hazards_results.csv", "wb") as f:
            writer = csv.writer(f, delimiter = ';')
            writer.writerows(a)
    return a

# generate_results_hazard()

# %% [markdown]
# ## Getting a table showing recording and type

# %%
# This table has also been used in another script when working with events.

def getKey0(item):
    return item[0]
    
a = [x[1:3] for x in results]
b_set = set(tuple(x) for x in a)
b = [ list(x) for x in b_set ]
b = sorted(b, key=getKey0)

# %% [markdown]
# # Generating heatmaps

# %%
# Reading the eye tracking data from 3 different files
if True:
    tmp = load_tsv("/media/sf_EyeTracking/data/short_1_30_unicode.txt")
    tmp.extend(load_tsv("/media/sf_EyeTracking/data/short_31_60_unicode.txt"))
    tmp.extend(load_tsv("/media/sf_EyeTracking/data/short_61_71_unicode.txt"))

print "Data contains " + str(len(tmp)) + " rows."

# Also contains the data when eyetracking fails because live events can be added at the same moment.
# Out:
# Data contains 2163736 rows.

# %%
def ms2mins(millis):
    millis = int(millis)
    seconds=(millis/1000)%60
    seconds = int(seconds)
    minutes=(millis/(1000*60))%60
    minutes = int(minutes)
    return ("%dm%ds" % (minutes, seconds))

def mins2ms(minutes, seconds, millis=0):
    return minutes * 60 * 1000 + seconds * 1000 + millis

# %%
def heatmap(usr, rec, start=-1, end=-1, title_ext="", save = False, hazard=""):
    
    participant = 0             # current participant ID
    recording_name = 1          # name of the recording
    recording_duration = 2      # recording duration 
    time_column = 3             # time indication
    gaze_x_column = 4           # x-position of the gaze point 
    gaze_y_column = 5           # y-position of the gaze point 
    pupil_diam_left = 6         # diameter of left pupil over time
    pupil_diam_right = 7        # diameter of right pupil over time       
    mt_column = 8               # movement type column
    md_column = 9               # movement duration column
    mi_column = 10              # movement index column
    event_column = 11           # Event type
   
    def get_time(usr, rec):
        coord = [int(line[time_column]) for line in tmp 
                 if line[participant] == usr and line[recording_name] == rec]
        if len(coord) == 0:
            return -1, -1
        return min(coord), max(coord) 
        
    if start == -1 and end == -1:
        start, end = get_time(usr, rec)
    
    if start == -1 and end == -1:
        return 
    
    # Selecting the values for one user and one recording.
    coord = [[line[gaze_x_column], line[gaze_y_column]] for line in tmp 
             if line[participant] == usr and line[recording_name] == rec
             and int(line[time_column]) < end 
             and int(line[time_column]) > start]
    
    
    # Converting to integers 
    def is_number(str):
        try:
            float(str)
            return True
        except:
            return False
    
    def toInt(l):
        return [int(i) for i in l if is_number(i)]
       
    coord = [toInt(l) for l in coord if len(toInt(l)) == 2]
 
    # Extracting the data
    x = [l[0] for l in coord]
    y = [l[1] for l in coord]
    x = np.asarray(x).astype(np.int)
    y = np.asarray(y).astype(np.int)
    
    # Printing the plot 
    title = "Participant " + usr + " (" + rec + ") from " + ms2mins(start) + " to " + ms2mins(end) + title_ext  
    print(title)
    
    if len(x) == 0 or len(y) == 0:
        print("No data to analyse")
        print(" ")
        return
    
    sns.plt.clf()
    sns.set(style="ticks")
    sns.jointplot(x, 1080-y, stat_func=kendalltau, kind="kde",
                     xlim=(0,1920), ylim=(0,1080))
    
    if save ==  True:
        output_dir = "/home/quentin/heatmap/" + hazard # + usr
        savefig( output_dir + '/' + title + '.png', bbox_inches='tight')
    
    # sns.plt.show()

# %%
heatmap(usr='42', rec='Recording172')
# Out:
# Participant 42 (Recording172) from 0m0s to 2m32s

# %%
def get_time_event(recording, hazard):
    info = [x for x in table if x[0] == hazard]
    lines = [x for x in tmp if x[1] == recording and x[11] == 'Logged live Event']
    
    if len(lines) not in [16, 17, 18]:
        print("Should have been a crash during recording.")
        return [-1, -1]
    
    if len(info) == 0:
        return [-1, -1]
    
    start = info[0][2] - 1
    end = info[0][3] - 1
    
    try:
        return [int(lines[start][3]), int(lines[end][3])]
    except:
        return [-1, -1]

    
def pick_times(from_seen, from_hazard):
    
    if from_seen == [0, 0]:
        return from_hazard
    
    if from_hazard == [-1,-1]:
        return from_seen
    
    result = []
    if from_seen[0] < from_hazard[0]:
        result.append(from_seen[0])
    else:
        result.append(from_hazard[0])
    if from_seen[1] > from_hazard[1]:
        result.append(from_seen[1])
    else:
        result.append(from_hazard[1])    
    return [int(r) for r in result]

# %%
from datetime import timedelta

participant_data = generate_data_per_participant()
hazard_data = generate_data_per_hazard()

def create_heatmap(data, usr, rec, hazard, seen, save = False):
    # Select correct information
    heatmap_data = [l for l in data if l[0] == usr and l[1] == rec and l[4] == hazard]
    
    def convert(time):
        r = (convert_time(time) - datetime(1900, 1, 1))
        triple = [(r.seconds//60)%60, (r.seconds)%60, r.microseconds//1000]
        return mins2ms(triple[0], triple[1], triple[2])
    
    if hazard in ['4AH', '4CH', '4AV', '4CV']:
        start, end = int(convert(heatmap_data[0][6])), int(convert(heatmap_data[0][14]))
    else:
        start, end = pick_times([int(convert(heatmap_data[0][6])), int(convert(heatmap_data[0][14]))], 
                             get_time_event(rec, hazard))
    
    # Goal heatmap creator function
    heatmap(usr, rec, start=start, end=end, title_ext= " for the hazard " + hazard + seen, hazard=hazard, save=save)

def heatmap_participant(p_data, usr, save= False):
    hazards_records = [[l[1], l[4], l[5]]  for l in p_data if l[0] == usr]
    for r in hazards_records:
        if r[2] == 'YES':
            create_heatmap(p_data, usr, r[0], r[1], ' seen', save=save)
        if r[2] == 'NO':
            create_heatmap(p_data, usr, r[0], r[1], ' not seen', save=save)
    print("User " + str(usr) + " done.")

def heatmap_hazard(h_data, hazard, save = False):
    hazards_records = [[l[0], l[1], l[5]]  for l in h_data if l[4] == hazard]

    for r in hazards_records:
        if r[2] == 'YES':
            create_heatmap(h_data, r[0], r[1], hazard, ' seen.', save=save)
        if r[2] == 'NO':
            create_heatmap(h_data, r[0], r[1], hazard, ' not seen.', save=save)
    print("Hazard " + str(hazard) + " done.")

# %%
# Equivalence between hazard and position of the logged live event
table = [['1AH', 1, 1, 2], ['3CH', 1, 3, 5], ['2AV', 1, 6, 8],
         ['5CV', 1, 9, 10], ['1CV', 1, 11, 12], ['6AV', 1, 13, 14],
         ['4AH', 1, 15, 15], ['6CH', 1, 16, 17], ['1CH', 2, 1, 2], 
         ['2AH', 2, 3, 5], ['4CV', 2, 6, 6], ['5AV', 2, 7, 8], 
         ['3AV', 2, 9, 11], ['3AH', 2, 12, 14], ['2CV', 2, 15, 17], 
         ['6AH', 2 ,18, 19], ['6CV', 3, 1, 2], ['4CH', 3, 3, 3], 
         ['5AH', 3, 4, 5], ['4AV', 3, 6, 6], ['5CH', 3, 7, 8], 
         ['2CH', 3, 9,11], ['3CV', 3, 12, 14], ['1AV', 3, 15, 16]]

# %%
# get_time_event("Recording007", '2CH') # -1, -1
start_ex, end_ex = get_time_event("Recording005", '1AH') 
heatmap('2', 'Recording005', start=start_ex, end=end_ex, title_ext="")
# Out:
# Participant 2 (Recording005) from 0m26s to 0m37s

# %%
# heatmap_participant(participant_data, '38', True)
# heatmap_hazard(hazard_data, '1CH', save=True)
# create_heatmap(participant_data, '30', 'Recording118', '2AV', ' seen')

# %%
hazard_values.sort()
for hazard in hazard_values:
    heatmap_hazard(hazard_data, hazard, save=True)
# Out:
# Participant 2 (Recording008) from 0m34s to 0m40s for the hazard 1AH seen.
# Participant 4 (Recording012) from 0m22s to 0m32s for the hazard 1AH seen.
# Participant 5 (Recording017) from 0m22s to 0m28s for the hazard 1AH seen.
# Participant 6 (Recording032) from 0m26s to 0m38s for the hazard 1AH seen.
# Participant 7 (Recording037) from 0m29s to 0m35s for the hazard 1AH seen.
# Participant 7 (Recording034) from 0m32s to 0m38s for the hazard 1AH seen.
for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 57 (Recording233) from 0m15s to 0m20s for the hazard 1CH seen.
# Participant 58 (Recording240) from 0m9s to 0m16s for the hazard 1CH seen.
# Participant 58 (Recording237) from 0m8s to 0m14s for the hazard 1CH not seen.
# Participant 59 (Recording244) from 0m14s to 0m20s for the hazard 1CH seen.
# Participant 59 (Recording241) from 0m13s to 0m18s for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 60 (Recording248) from 0m17s to 0m23s for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 60 (Recording245) from 0m0s to 3m19s for the hazard 1CH not seen.
# Should have been a crash during recording.
# Participant 61 (Recording252) from 0m10s to 0m18s for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 62 (Recording256) from 0m14s to 0m19s for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 63 (Recording261) from 0m13s to 0m19s for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 63 (Recording258) from 0m19s to 0m21s for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 64 (Recording264) from 0m27s to 0m33s for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 65 (Recording268) from 0m27s to 0m32s for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 66 (Recording274) from 0m17s to 0m24s for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 66 (Recording271) from 0m28s to 0m33s for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 67 (Recording278) from 0m15s to 0m24s for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 68 (Recording282) from 0m21s to 0m28s for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 69 (Recording287) from 0m27s to 0m33s for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 69 (Recording284) from 0m23s to 0m25s for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 70 (Recording289) from 0m19s to 0m23s for the hazard 1CH seen.
# Should have been a crash during recording.
# Participant 71 (Recording293) from 0m16s to 0m22s for the hazard 1CH seen.
# Hazard 1CH done.
# Participant 2 (Recording008) from 2m14s to 2m30s for the hazard 1CV seen.
# Participant 4 (Recording012) from 2m8s to 2m15s for the hazard 1CV seen.
# Participant 5 (Recording017) from 1m54s to 2m0s for the hazard 1CV seen.
# Participant 6 (Recording032) from 2m22s to 2m32s for the hazard 1CV seen.
# Participant 7 (Recording037) from 2m11s to 2m16s for the hazard 1CV seen.
# Participant 7 (Recording034) from 2m16s to 2m21s for the hazard 1CV seen.
# Participant 8 (Recording041) from 1m54s to 2m2s for the hazard 1CV seen.
# Participant 8 (Recording038) from 1m50s to 2m0s for the hazard 1CV seen.
# Participant 9 (Recording043) from 1m49s to 1m54s for the hazard 1CV seen.
# Participant 11 (Recording049) from 2m14s to 2m24s for the hazard 1CV seen.
# Participant 12 (Recording053) from 1m52s to 1m56s for the hazard 1CV seen.
# Participant 13 (Recording058) from 2m1s to 2m7s for the hazard 1CV seen.
# Participant 13 (Recording055) from 1m59s to 2m8s for the hazard 1CV seen.
# Participant 14 (Recording063) from 1m35s to 1m41s for the hazard 1CV seen.
# Participant 14 (Recording060) from 1m33s to 1m38s for the hazard 1CV seen.
# Participant 15 (Recording067) from 2m0s to 2m6s for the hazard 1CV seen.
# Participant 16 (Recording072) from 1m51s to 2m1s for the hazard 1CV seen.
# Participant 16 (Recording069) from 1m55s to 2m6s for the hazard 1CV seen.
# Participant 17 (Recording075) from 1m47s to 1m52s for the hazard 1CV seen.
# Participant 18 (Recording079) from 1m56s to 2m8s for the hazard 1CV seen.
# Participant 20 (Recording082) from 1m45s to 1m49s for the hazard 1CV seen.
# Participant 21 (Recording085) from 1m49s to 1m54s for the hazard 1CV seen.
# Participant 22 (Recording089) from 2m5s to 2m12s for the hazard 1CV seen.
# Participant 23 (Recording094) from 1m48s to 1m54s for the hazard 1CV seen.
# Participant 24 (Recording098) from 2m2s to 2m10s for the hazard 1CV seen.
# Participant 25 (Recording103) from 1m40s to 1m45s for the hazard 1CV seen.
# Participant 27 (Recording108) from 1m47s to 1m55s for the hazard 1CV seen.
# Participant 27 (Recording105) from 1m59s to 2m6s for the hazard 1CV seen.
# Participant 28 (Recording112) from 2m3s to 2m10s for the hazard 1CV not seen.
# Participant 28 (Recording109) from 1m47s to 1m52s for the hazard 1CV seen.
# Participant 29 (Recording114) from 1m57s to 2m4s for the hazard 1CV seen.
# Participant 30 (Recording118) from 2m21s to 2m31s for the hazard 1CV seen.
# Participant 31 (Recording124) from 2m11s to 2m18s for the hazard 1CV seen.
# Participant 33 (Recording133) from 2m2s to 2m7s for the hazard 1CV seen.
# Participant 33 (Recording129) from 2m18s to 2m24s for the hazard 1CV seen.
# Participant 34 (Recording138) from 2m21s to 2m32s for the hazard 1CV seen.
# Participant 34 (Recording134) from 3m5s to 3m16s for the hazard 1CV seen.
# Participant 36 (Recording144) from 1m58s to 2m5s for the hazard 1CV seen.
# Should have been a crash during recording.
# Participant 38 (Recordnig153) from 2m15s to 2m23s for the hazard 1CV seen.
# No data to analyse
#
# Participant 39 (Recording157) from 2m4s to 2m12s for the hazard 1CV seen.
# Participant 40 (Recording161) from 2m22s to 2m32s for the hazard 1CV seen.
# Participant 41 (Recording168) from 1m45s to 1m50s for the hazard 1CV seen.
# Participant 41 (Recording164) from 1m39s to 1m47s for the hazard 1CV seen.
# Participant 42 (Recording171) from 1m57s to 2m4s for the hazard 1CV seen.
# Participant 43 (Recording175) from 1m44s to 1m50s for the hazard 1CV seen.
# Participant 45 (Recording185) from 1m56s to 2m1s for the hazard 1CV seen.
# Participant 46 (Recording190) from 1m46s to 1m52s for the hazard 1CV seen.
# Participant 47 (Recording192) from 2m11s to 2m19s for the hazard 1CV seen.
# Participant 48 (Recording197) from 1m40s to 1m46s for the hazard 1CV seen.
# Participant 49 (Recording200) from 2m2s to 2m11s for the hazard 1CV seen.
# Participant 50 (Recording206) from 1m38s to 1m42s for the hazard 1CV seen.
# Participant 50 (Recording203) from 1m51s to 2m4s for the hazard 1CV seen.
# Participant 51 (Recording208) from 2m0s to 2m4s for the hazard 1CV seen.
# Participant 52 (Recording214) from 2m5s to 2m12s for the hazard 1CV seen.
# Participant 53 (Recording219) from 1m37s to 1m43s for the hazard 1CV seen.
# Participant 53 (Recording216) from 2m1s to 2m6s for the hazard 1CV seen.
# Participant 54 (Recording222) from 1m51s to 1m58s for the hazard 1CV seen.
# Participant 55 (Recording225) from 1m39s to 1m44s for the hazard 1CV seen.
# Should have been a crash during recording.
# Participant 56 (Recording231) from 1m39s to 1m47s for the hazard 1CV seen.
# Participant 57 (Recording235) from 1m18s to 2m8s for the hazard 1CV seen.
# Participant 58 (Recording239) from 1m50s to 1m57s for the hazard 1CV seen.
# Participant 59 (Recording243) from 1m3s to 1m40s for the hazard 1CV seen.
# Participant 60 (Recording247) from 2m2s to 2m12s for the hazard 1CV seen.
# Should have been a crash during recording.
# Participant 61 (Recording251) from 1m35s to 1m41s for the hazard 1CV seen.
# Participant 62 (Recording257) from 1m39s to 1m44s for the hazard 1CV seen.
# Participant 62 (Recording254) from 1m40s to 1m45s for the hazard 1CV seen.
# Participant 63 (Recording259) from 1m40s to 1m47s for the hazard 1CV seen.
# Participant 64 (Recording265) from 2m6s to 2m12s for the hazard 1CV seen.
# Participant 65 (Recording270) from 1m50s to 1m59s for the hazard 1CV seen.
# Participant 65 (Recording267) from 2m0s to 2m10s for the hazard 1CV seen.
# Participant 66 (Recording273) from 1m57s to 2m2s for the hazard 1CV seen.
# Participant 67 (Recording276) from 2m0s to 2m10s for the hazard 1CV seen.
# Participant 68 (Recording283) from 2m1s to 2m9s for the hazard 1CV seen.
# Participant 68 (Recording280) from 2m19s to 2m29s for the hazard 1CV seen.
# Participant 69 (Recording285) from 1m50s to 1m57s for the hazard 1CV seen.
# Participant 70 (Recording290) from 1m47s to 1m53s for the hazard 1CV seen.
# Participant 71 (Recording295) from 1m43s to 1m48s for the hazard 1CV seen.
# Participant 71 (Recording292) from 2m27s to 2m35s for the hazard 1CV seen.
# Hazard 1CV done.
# Should have been a crash during recording.
# Participant 2 (Recording007) from 0m58s to 1m6s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 4 (Recording013) from 0m33s to 0m40s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 5 (Recording019) from 0m41s to 0m48s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 5 (Recording018) from 0m48s to 0m54s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 6 (Recording031) from 1m2s to 1m11s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 7 (Recording035) from 0m58s to 1m5s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 8 (Recording040) from 0m45s to 0m54s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 9 (Recording045) from 0m56s to 1m0s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 9 (Recording042) from 0m59s to 1m5s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 11 (Recording047) from 0m0s to 2m58s for the hazard 2AH not seen.
# Should have been a crash during recording.
# Participant 12 (Recording052) from 0m30s to 0m35s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 13 (Recording056) from 0m56s to 1m3s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 14 (Recording062) from 0m39s to 0m42s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 15 (Recording068) from 0m45s to 0m52s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 15 (Recording064) from 1m10s to 1m14s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 16 (Recording071) from 0m41s to 0m49s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 17 (Recording076) from 0m46s to 0m51s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 17 (Recording073) from 0m50s to 0m55s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 18 (Recording078) from 0m53s to 1m2s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 20 (Recording083) from 0m44s to 0m48s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 21 (Recording086) from 0m0s to 2m35s for the hazard 2AH not seen.
# Should have been a crash during recording.
# Participant 22 (Recording091) from 0m45s to 0m53s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 23 (Recording096) from 0m41s to 0m49s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 23 (Recording093) from 0m45s to 0m50s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 24 (Recording099) from 0m50s to 0m56s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 25 (Recording104) from 0m46s to 0m53s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 25 (Recording101) from 0m0s to 2m29s for the hazard 2AH not seen.
# Should have been a crash during recording.
# Participant 27 (Recording106) from 0m49s to 0m57s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 28 (Recording111) from 0m45s to 0m50s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 29 (Recording116) from 0m49s to 0m51s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 29 (Recording113) from 0m50s to 0m59s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 30 (Recording119) from 0m59s to 1m6s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 31 (Recording125) from 0m49s to 0m54s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 31 (Recording122) from 0m52s to 1m2s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 33 (Recording130) from 0m43s to 0m50s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 34 (Recording136) from 1m0s to 1m8s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 36 (Recording145) from 0m54s to 1m0s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 38 (Recording152) from 0m56s to 1m1s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant 39 (Recording156) from 0m57s to 1m0s for the hazard 2AH seen.
# Should have been a crash during recording.
# Participant
# Participant 44 (Recording183) from 1m23s to 1m31s for the hazard 2AV seen.
# Participant 45 (Recording185) from 1m10s to 1m20s for the hazard 2AV seen.
# Participant 46 (Recording190) from 0m59s to 1m8s for the hazard 2AV seen.
# Participant 47 (Recording192) from 1m18s to 1m27s for the hazard 2AV seen.
# Participant 48 (Recording197) from 0m54s to 1m4s for the hazard 2AV seen.
# Participant 49 (Recording200) from 1m1s to 1m16s for the hazard 2AV seen.
# Participant 50 (Recording206) from 0m52s to 1m1s for the hazard 2AV seen.
# Participant 50 (Recording203) from 1m0s to 1m10s for the hazard 2AV seen.
# Participant 51 (Recording208) from 1m14s to 1m23s for the hazard 2AV seen.
# Participant 52 (Recording214) from 1m18s to 1m27s for the hazard 2AV seen.
# Participant 53 (Recording219) from 0m54s to 1m2s for the hazard 2AV seen.
# Participant 53 (Recording216) from 1m13s to 1m22s for the hazard 2AV seen.
# Participant 54 (Recording222) from 1m3s to 1m13s for the hazard 2AV seen.
# Participant 55 (Recording225) from 0m55s to 1m3s for the hazard 2AV seen.
# Should have been a crash during recording.
# Participant 56 (Recording231) from 1m8s to 1m16s for the hazard 2AV seen.
# Participant 57 (Recording235) from 0m45s to 1m22s for the hazard 2AV seen.
# Participant 58 (Recording239) from 0m59s to 1m10s for the hazard 2AV seen.
# Participant 59 (Recording243) from 0m37s to 1m6s for the hazard 2AV seen.
# Participant 60 (Recording247) from 1m4s to 1m17s for the hazard 2AV seen.
# Should have been a crash during recording.
# Participant 61 (Recording251) from 1m0s to 1m9s for the hazard 2AV seen.
# Participant 62 (Recording257) from 0m55s to 1m4s for the hazard 2AV seen.
# Participant 62 (Recording254) from 0m53s to 1m3s for the hazard 2AV seen.
# Participant 63 (Recording259) from 0m54s to 1m3s for the hazard 2AV seen.
# Participant 64 (Recording265) from 1m15s to 1m25s for the hazard 2AV seen.
# Participant 65 (Recording270) from 1m0s to 1m9s for the hazard 2AV seen.
# Participant 65 (Recording267) from 1m7s to 1m17s for the hazard 2AV seen.
# Participant 66 (Recording273) from 1m8s to 1m18s for the hazard 2AV seen.
# Participant 67 (Recording276) from 1m7s to 1m21s for the hazard 2AV seen.
# Participant 68 (Recording283) from 1m14s to 1m25s for the hazard 2AV seen.
# Participant 68 (Recording280) from 1m21s to 1m33s for the hazard 2AV seen.
# Participant 69 (Recording285) from 1m2s to 1m14s for the hazard 2AV seen.
# Participant 70 (Recording290) from 0m59s to 1m8s for the hazard 2AV seen.
# Participant 71 (Recording295) from 0m58s to 1m8s for the hazard 2AV seen.
# Participant 71 (Recording292) from 1m23s to 1m38s for the hazard 2AV seen.
# Hazard 2AV done.
# Participant 2 (Recording009) from 1m49s to 1m57s for the hazard 2CH seen.
# Participant 2 (Recording005) from 2m3s to 2m11s for the hazard 2CH seen.
# Participant 4 (Recording014) from 1m29s to 1m37s for the hazard 2CH seen.
# Participant 4 (Recording011) from 1m31s to 1m40s for the hazard 2CH not seen.
# Participant 5 (Recording016) from 1m23s to 1m31s for the hazard 2CH seen.
# Participant 55 (Recording228) from 0m10s to 0m17s for the hazard 6CV seen.
# Participant 55 (Recording224) from 0m11s to 0m18s for the hazard 6CV not seen.
# Participant 56 (Recording230) from 0m11s to 0m19s for the hazard 6CV seen.
# Participant 57 (Recording234) from 0m15s to 0m21s for the hazard 6CV seen.
# Should have been a crash during recording.
# Participant 58 (Recording238) from 0m18s to 0m24s for the hazard 6CV seen.
# Should have been a crash during recording.
# Participant 59 (Recording242) from 0m15s to 0m18s for the hazard 6CV seen.
# Participant 60 (Recording246) from 0m10s to 0m19s for the hazard 6CV seen.
# Participant 61 (Recording253) from 0m10s to 0m19s for the hazard 6CV not seen.
# Participant 61 (Recording249) from 0m11s to 0m17s for the hazard 6CV seen.
# Participant 62 (Recording255) from 0m10s to 0m17s for the hazard 6CV seen.
# Participant 64 (Recording266) from 0m19s to 0m26s for the hazard 6CV seen.
# Participant 64 (Recording262) from 0m24s to 0m34s for the hazard 6CV seen.
# Participant 65 (Recording269) from 0m19s to 0m28s for the hazard 6CV seen.
# Participant 66 (Recording272) from 0m14s to 0m23s for the hazard 6CV seen.
# Participant 67 (Recording279) from 0m16s to 0m24s for the hazard 6CV seen.
# Participant 67 (Recording275) from 0m15s to 0m23s for the hazard 6CV seen.
# Participant 68 (Recording281) from 0m19s to 0m28s for the hazard 6CV seen.
# Participant 69 (Recording286) from 0m15s to 0m22s for the hazard 6CV seen.
# Participant 70 (Recording291) from 0m13s to 0m21s for the hazard 6CV not seen.
# Participant 70 (Recording288) from 0m26s to 0m36s for the hazard 6CV seen.
# Participant 71 (Recording294) from 0m23s to 0m30s for the hazard 6CV seen.
# Hazard 6CV done.

# %%
participant_values.sort()

# done except 38, 56, 57
for participant in participant_values:
    heatmap_participant(participant_data, participant, save=True)
# Out:
# Participant 38 (Recording154) from 0m25s to 0m33s for the hazard 6CV seen
# Participant 38 (Recording154) from 0m34s to 0m42s for the hazard 4CH seen
# Participant 38 (Recording154) from 0m49s to 1m0s for the hazard 5AH not seen
# Participant 38 (Recording154) from 1m16s to 1m23s for the hazard 4AV seen
# Participant 38 (Recording154) from 1m24s to 1m34s for the hazard 5CH seen
# Participant 38 (Recording154) from 1m49s to 1m58s for the hazard 2CH seen
# Participant 38 (Recording154) from 2m13s to 2m23s for the hazard 3CV seen
# Participant 38 (Recording154) from 2m45s to 2m54s for the hazard 1AV seen
# Should have been a crash during recording.
# Participant 38 (Recordnig153) from 0m31s to 0m37s for the hazard 1AH seen
# No data to analyse
#
# Should have been a crash during recording.
# Participant 38 (Recordnig153) from 0m57s to 1m7s for the hazard 2CH seen
# No data to analyse
#
# Should have been a crash during recording.
# Participant 38 (Recordnig153) from 1m26s to 1m34s for the hazard 2AV seen
# No data to analyse
#
# Should have been a crash during recording.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-287-101321da76e8> in <module>()
#       3 # done except 38, 56, 57
#       4 for participant in ['38', '56', '57']: # participant_values:
# ----> 5     heatmap_participant(participant_data, participant, save=True)
#
# <ipython-input-280-8b16fead5268> in heatmap_participant(p_data, usr, save)
#      28             create_heatmap(p_data, usr, r[0], r[1], ' seen', save=save)
#      29         if r[2] == 'NO':
# ---> 30             create_heatmap(p_data, usr, r[0], r[1], ' not seen', save=save)
#      31     print("User " + str(usr) + " done.")
#      32
#
# <ipython-input-280-8b16fead5268> in create_heatmap(data, usr, rec, hazard, seen, save)
#      20
#      21     # Goal heatmap creator function
# ---> 22     heatmap(usr, rec, start=start, end=end, title_ext= " for the hazard " + hazard + seen, save=save)
#      23
#      24 def heatmap_participant(p_data, usr, save= False):
#
# <ipython-input-256-58dfadf3be08> in heatmap(usr, rec, start, end, title_ext, save)
#      20
#      21     if start == -1 and end == -1:
# ---> 22         start, end = get_time(usr, rec)
#      23
#      24     # Selecting the values for one user and one recording.
#
# <ipython-input-256-58dfadf3be08> in get_time(usr, rec)
#      17         coord = [int(line[time_column]) for line in tmp
#      18                  if line[participant] == usr and line[recording_name] == rec]
# ---> 19         return min(coord), max(coord)
#      20
#      21     if start == -1 and end == -1:
#
# ValueError: min() arg is an empty sequence

# %% [markdown]
# ## Clustering

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler

# %%
X = [[x[0], x[1], x[3], x[5], x[7]] for x in generate_results_participant()[1:]]

# %%
def getKey(item):
    try: 
        return int(item[0])
    except:
        return 0
    
X = sorted(X, key=getKey)
X
# Out:
# [['0', 85, 1.083, 5.994, 21.998],
#  ['2', 81, 1.183, 3.259, 21.641],
#  ['4', 78, 1.033, 2.595, 22.162],
#  ['5', 93, 1.522, 2.937, 25.363],
#  ['6', 96, 1.416, 3.267, 24.992],
#  ['7', 84, 0.649, 2.817, 18.709],
#  ['8', 84, 0.638, 2.573, 19.164],
#  ['9', 78, 0.79, 1.738, 19.745],
#  ['11', 79, 1.448, 2.809, 17.612],
#  ['12', 90, 0.516, 11.599, 21.239],
#  ['13', 90, 0.804, 22.378, 17.96],
#  ['14', 78, 0.749, 1.752, 17.353],
#  ['15', 100, 1.41, 2.126, 20.646],
#  ['16', 87, 1.31, 3.022, 16.795],
#  ['17', 81, 0.947, 1.39, 25.407],
#  ['18', 81, 0.596, 5.888, 21.419],
#  ['20', 65, 0.742, 25.576, 19.992],
#  ['21', 80, 0.657, 2.2, 18.819],
#  ['22', 92, 1.237, 2.404, 23.946],
#  ['23', 68, 0.906, 1.59, 19.077],
#  ['24', 81, 0.801, 2.179, 21.176],
#  ['25', 71, 0.487, 24.553, 18.604],
#  ['27', 84, 0.602, 2.428, 21.959],
#  ['28', 81, 1.079, 2.14, 20.66],
#  ['29', 78, 0.975, 2.27, 19.217],
#  ['30', 93, 1.021, 3.569, 21.004],
#  ['31', 84, 1.763, 2.721, 22.343],
#  ['33', 87, 1.062, 2.252, 23.494],
#  ['34', 90, 0.723, 3.399, 17.434],
#  ['36', 87, 0.753, 2.576, 17.546],
#  ['38', 84, 1.467, 2.628, 22.613],
#  ['39', 87, 0.859, 2.578, 18.786],
#  ['40', 96, 1.362, 2.887, 17.514],
#  ['41', 81, 0.82, 2.329, 20.249],
#  ['42', 90, 1.172, 2.446, 21.249],
#  ['43', 79, 0.812, 2.17, 20.515],
#  ['44', 100, 0.647, 2.212, 21.092],
#  ['45', 83, 0.843, 1.817, 20.946],
#  ['46', 95, 1.819, 2.407, 21.638],
#  ['47', 95, 0.826, 2.048, 27.688],
#  ['48', 84, 1.32, 1.95, 22.836],
#  ['49', 96, 0.563, 3.094, 22.21],
#  ['50', 81, 1.049, 2.5, 23.185],
#  ['51', 87, 0.79, 1.742, 23.913],
#  ['52', 78, 0.588, 1.939, 17.345],
#  ['53', 84, 0.622, 2.032, 17.914],
#  ['54', 93, 1.524, 2.24, 26.354],
#  ['55', 68, 1.08, 1.864, 21.402],
#  ['56', 90, 0.697, 3.555, 22.41],
#  ['57', 96, 1.551, 2.603, 17.893],
#  ['58', 90, 0.993, 3.375, 21.826],
#  ['59', 90, 0.988, 3.377, 20.086],
#  ['60', 81, 0.938, 3.192, 26.07],
#  ['61', 82, 1.491, 3.052, 20.326],
#  ['62', 90, 0.724, 1.771, 20.282],
#  ['63', 90, 0.626, 1.775, 18.491],
#  ['64', 87, 0.681, 2.403, 22.495],
#  ['65', 93, 0.981, 4.039, 20.536],
#  ['66', 100, 1.432, 1.838, 21.661],
#  ['67', 87, 0.842, 2.805, 21.501],
#  ['68', 96, 0.809, 2.686, 19.246],
#  ['69', 81, 1.476, 2.03, 20.506],
#  ['70', 75, 0.734, 2.018, 17.792],
#  ['71', 87, 0.778, 2.771, 21.43]]

# %%
from sklearn.cluster import KMeans
X_bis = [x[1:] for x in X]
X_bis = np.array(X_bis)
kmeans = KMeans(n_clusters=2).fit(X_bis)
clusters = kmeans.predict(X_bis)

cluster_1 = []
cluster_2 = []
for i in range(0, len(clusters)):
    if clusters[i] == 1: 
        cluster_1.append(X[i])
    if clusters[i] == 0:
        cluster_2.append(X[i])

header = ['ID', 'Accuracy', 'First fixation', 'Time laps', 'Percentage fixation']
cluster_1 = pd.DataFrame(cluster_1, columns = header)
cluster_2 = pd.DataFrame(cluster_2, columns = header)

# %%
print cluster_1['ID'].values.tolist()
print cluster_1['Accuracy'].mean()
print cluster_1['First fixation'].mean()
print cluster_1['Time laps'].mean()
print cluster_1['Percentage fixation'].mean()
# Out:
# ['0', '2', '4', '7', '8', '9', '11', '14', '17', '18', '20', '21', '23', '24', '25', '27', '28', '29', '31', '38', '41', '43', '45', '48', '50', '52', '53', '55', '60', '61', '69', '70']
# 79.4375
# 0.949
# 3.93728125
# 20.586125

# %%
print cluster_2['ID'].values.tolist()
print cluster_2['Accuracy'].mean()
print cluster_2['First fixation'].mean()
print cluster_2['Time laps'].mean()
print cluster_2['Percentage fixation'].mean()
# Out:
# ['5', '6', '12', '13', '15', '16', '22', '30', '33', '34', '36', '39', '40', '42', '44', '46', '47', '49', '51', '54', '56', '57', '58', '59', '62', '63', '64', '65', '66', '67', '68', '71']
# 91.875
# 1.0136875
# 3.56815625
# 21.21
